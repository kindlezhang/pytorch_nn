# %% [markdown]
# # Vision Transformer

# %% [markdown]
# the model article can  be found here: [An Image is Worth 16x16 Words: Transformers for Image Recognition at Scale](https://arxiv.org/abs/2010.11929 "article here")
#
# the github repository can be found here: [vision transformer](https://github.com/google-research/vision_transformer "code here")
